# %%
from sklearn import tree

features= [[140,1],[130,1],[150,0],[170,0]]  #wt,texture 1-bumpy and 0- smooth
label = [0,0,1,1] #0=Orange  1= Apple

clf = tree.DecisionTreeClassifier()

clf = clf.fit(features,label)

print(clf.predict([[150,0]]))
# Out:
# [1]
